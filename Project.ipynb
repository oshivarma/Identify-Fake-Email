# %%
# !git clone https://github.com/eragonruan/text-detection-ctpn
# Out:
# Cloning into 'text-detection-ctpn'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1070 (delta 0), reused 0 (delta 0), pack-reused 1067
# Receiving objects: 100% (1070/1070), 344.22 MiB | 39.22 MiB/s, done.
# Resolving deltas: 100% (440/440), done.

# %%
# %cd text-detection-ctpn/utils/bbox/
# Out:
# /content/text-detection-ctpn/utils/bbox

# %%
# !chmod +x make.sh

# %%
# !./make.sh
# Out:
# running install
# running build
# running build_ext
# building 'bbox' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c bbox.c -o build/temp.linux-x86_64-3.7/bbox.o
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
# ...

# %%
len(os.listdir('data/dataset/mlt/image/'))
# Out:
# 704

# %%
# !pip install tensorflow==1.14
# Out:
# ...
#      |████████████████████████████████| 109.3MB 111kB/s
# ...
#      |████████████████████████████████| 3.2MB 45.1MB/s
# ...
#      |████████████████████████████████| 491kB 49.6MB/s
# ...
#      |████████████████████████████████| 51kB 7.2MB/s
# ...
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# ...

# %%
# !python ./main/demo.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# %cd /content/text-detection-ctpn/data
# Out:
# /content/text-detection-ctpn/data

# %%
import shutil
shutil.move("/content/drive/MyDrive/vgg_16.ckpt", "/content/text-detection-ctpn/data/")
# Out:
# '/content/text-detection-ctpn/data/vgg_16.ckpt'

# %%
shutil.move("/content/drive/MyDrive/ctpn_50000.ckpt.data-00000-of-00001", "/content/text-detection-ctpn/checkpoints_mlt/")
# Out:
# '/content/text-detection-ctpn/checkpoints_mlt/ctpn_50000.ckpt.data-00000-of-00001'

# %%
shutil.move("/content/drive/MyDrive/dataset/image", "/content/text-detection-ctpn/data/dataset/mlt/")
# Out:
# '/content/text-detection-ctpn/data/dataset/mlt/image'

# %%
len(os.listdir('/content/text-detection-ctpn/data/dataset/mlt/image/'))
# Out:
# 704

# %% [markdown]
# Delete Content of a file

# %%
import os, shutil
folder = '/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/label/'
for filename in os.listdir(folder):
    file_path = os.path.join(folder, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
    except Exception as e:
        print('Failed to delete %s. Reason: %s' % (file_path, e))

# %%
# %cd data/dataset/mlt/label
# Out:
# /content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/label

# %%
import glob
import os
pp="/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/label/"
os.chdir(r'/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/label/')
myFiles = glob.glob('*.txt')
for img in myFiles:
  f = open(os.path.join(pp,img), "r")
  l=f.read()
  f.close()
  r=l.split()
  f=open(img, "w")
  f.close()
  for i in r:
    a,b,c,d=i.split(',')
    m=open(img, "a")
    m.write(a+','+b+','+c+','+d)
    m.write("\n")
    m.close()

# %%
# %cd /content/text-detection-ctpn
# Out:
# /content/text-detection-ctpn

# %%
# !python ./main/train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !git clone https://github.com/zzzDavid/ICDAR-2019-SROIE
# Out:
# Cloning into 'ICDAR-2019-SROIE'...
# remote: Enumerating objects: 2386, done.
# remote: Total 2386 (delta 0), reused 0 (delta 0), pack-reused 2386
# Receiving objects: 100% (2386/2386), 278.63 MiB | 37.95 MiB/s, done.
# Resolving deltas: 100% (211/211), done.
# Checking out files: 100% (1980/1980), done.

# %%
import shutil
shutil.move("/content/text-detection-ctpn/data/vgg_16.ckpt","/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data")
# Out:
# '/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/vgg_16.ckpt'

# %%
import shutil
shutil.move("/content/drive/MyDrive/dataset/image","/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/")
# Out:
# '/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/image'

# %%
shutil.move("/content/text-detection-ctpn/data/dataset/mlt/label", "/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/")
# Out:
# '/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/label'

# %%
# %cd task1/CTPN\ Method/
# Out:
# [Errno 2] No such file or directory: 'task1/CTPN Method/'
# /content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method

# %%
# %cd utils/bbox
# !chmod +x make.sh
! ./make.sh
# Out:
# /content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/utils/bbox
# running install
# running build
# running build_ext
# building 'bbox' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-a56wZI/python3.7-3.7.10=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c bbox.c -o build/temp.linux-x86_64-3.7/bbox.o
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
#                  from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
# ...

# %%
ls
# Out:
# bbox.c                                 nms.c
# bbox.cpython-37m-x86_64-linux-gnu.so*  nms.cpython-37m-x86_64-linux-gnu.so*
# bbox.pyx                               nms.pyx
# bbox_transform.py                      setup.py
# make.sh*

# %%
import shutil
shutil.move("/content/drive/MyDrive/dataset/original","/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/")

# %%
len(os.listdir("/content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/mlt/image/"))
# Out:
# 704

# %%
# %cd ICDAR-2019-SROIE/task1/CTPN Method/
# Out:
# /content/text-detection-ctpn/ICDAR-2019-SROIE/task1/CTPN Method

# %%
# !python ./main/train.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
